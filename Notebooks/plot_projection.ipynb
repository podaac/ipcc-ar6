# %% [markdown]
# ## AR6 local sea-level projections
# In this notebook, we will make a plot of the time series of regional sea level based on the IPCC AR6 projections.
#
# ### Prerequisites
# This package requires some dependencies. To install with Anaconda/Miniconda, run
# `conda install numpy matplotlib pandas openpyxl`
#
# To install with pip
# `pip install numpy matplotlib pandas openpyxl`

# %%
import ipywidgets as widgets
import plot_functions as plf

filename = '../Data/ipcc_ar6_sea_level_projection_psmsl_id_24.xlsx'

# %% [markdown]
# Select a shared socio-economic pathway (SSP) scenario, a specific process (To see total sea-level changes due to all processes together, select 'Total'), and the confidence to see the specific projections.

# %%
scenario,process,confidence = plf.define_widgets()
plf.read_and_plot(scenario=scenario.value, process=process.value, confidence=confidence.value,filename=filename)
output = widgets.interact(plf.read_and_plot,scenario=scenario, process=process, confidence=confidence,filename=widgets.fixed(filename))
# Out:
# interactive(children=(Dropdown(description='Scenario:', index=2, options=('SSP1.19', 'SSP1.26', 'SSP2.45', 'SS…
